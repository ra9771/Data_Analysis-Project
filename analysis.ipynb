# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
#number of row and column in data frame
df.shape
# Out:
# (11251, 15)

# %%
#it is method of pandas to return first few row of data frame 
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
#it is method that hives a summery of data frames including:
#Number of rows and column 
#columnn name 
#non-null values count
#data type of each column
#Memory Usages

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop unrelated/blank columns:-

#df.drop(['status','unnamed1'],axis=1,inplace=True)
columns_to_drop = [col for col in ['status', 'unnamed1'] if col in df.columns]
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
#check for null values:-

pd.isnull(df).sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# dtype: int64

# %%
#drop null value:-
df.dropna(inplace=True)

# %%
#change Data type:-
df['Amount'].dtypes
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status'],
#       dtype='object')

# %%
#rename columns names:-
df.rename(columns={'Marital_Status':'Shaadi'})
# Out:
# Empty DataFrame
# Columns: [User_ID, Cust_name, Product_ID, Gender, Age Group, Age, Shaadi, State, Zone, Occupation, Product_Category, Orders, Amount, Status]
# Index: []

# %%
#descrine () method return description of the data in the DataFrame(i.e. count, mean, std , stc)
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
# use describe for specific column:-

df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11239.000000
# mean      35.421207      2.489290   9453.610858
# std       12.754122      1.115047   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
#Exploratory Data Analysis:--
#Gender
# Out:
#   Cell In[67], line 1
#     Exploratory Data Analysis:--
#                 ^
# SyntaxError: invalid syntax

# %%
#plot a bar chart for gender and its count :

ax=sns.countplot(x='Gender',data = df,hue='Gender',palette={'M': 'orange', 'F': 'blue'})

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#plotting the chart for gender vs total amount:--
sales_gen = df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by = 'Amount',ascending=False)

sns.barplot(x = 'Gender', y = 'Amount' , data = sales_gen, hue='Gender',palette={'M': 'orange', 'F': 'blue'})
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# From above graph we can see that most of the buyers are female and even the purchhasing power of females are greater than mens.

# %%
#Age:

# %%
ax = sns.countplot(data = df, x = 'Age Group',hue='Gender',palette={'M': 'orange', 'F': 'blue'})

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
# Group and sort data
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Create a list of unique colors — one for each Age Group
num_age_groups = sales_age['Age Group'].nunique()
colors = sns.color_palette('Set2', num_age_groups)  # Or try 'pastel', 'husl', etc.

# Plot without using hue (not needed here as data is already grouped)
ax = sns.barplot(x='Age Group', y='Amount', data=sales_age, palette=colors)

plt.title("Total Sales Amount by Age Group")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4752\98919161.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Age Group', y='Amount', data=sales_age, palette=colors)
# Text(0.5, 1.0, 'Total Sales Amount by Age Group')

# %%
# total number of orders from top 10 states

# Grouping and sorting the data
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

# Set figure size
sns.set(rc={'figure.figsize': (15, 5)})


# Create the barplot
ax = sns.barplot(data=sales_state, x='State', y='Orders',hue='State', palette=colors)

# %%
#total amount/sales from top 10 states

sales_state = df.groupby(['State'],as_index = False)['Amount'].sum().sort_values(by = 'Amount',ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State', y = 'Amount',hue = 'State',palette=colors)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
# Group and sort the data
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

# Set figure size
sns.set(rc={'figure.figsize': (15, 5)})


# Plotting the barplot
ax = sns.barplot(data=sales_state, x='State', y='Amount',hue='State', palette=colors)

# %% [markdown]
# From above graphs we can see thar most of the order & total Sales/amount
# are from utterpradesh, Maharastra and Karanatka respectively

# %%
ax = sns.countplot(data = df, x = 'Marital_Status',palette={'0': 'orange', '1': 'blue'})

sns.set(rc={'figure.figsize':(3,2)})
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4408\3030541134.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Marital_Status',palette={'0': 'orange', '1': 'blue'})

# %%
# Grouping and aggregating
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum()

# Sorting
sales_state = sales_state.sort_values(by='Amount', ascending=False)



sns.set(rc={'figure.figsize':(6, 5)})
sns.barplot(data=sales_state, x='Marital_Status', y='Amount', hue='Gender')
plt.title("Total Sales by Marital Status and Gender")
plt.show()

# %% [markdown]
# Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation', palette='viridis')

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4752\2450750666.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Occupation', palette='viridis')

# %%
# Grouping and sorting data
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Set the figure size
sns.set(rc={'figure.figsize':(20,5)})

# Create a colorful barplot
sns.barplot(data=sales_state, x='Occupation', y='Amount', palette='viridis')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4752\2894383536.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_state, x='Occupation', y='Amount', palette='viridis')
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of  the buyers are working in IT, Healthcare and Aviation sector

# %% [raw]
# Product Category:-

# %%
sns.set(rc = {'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category',palette='viridis')

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4752\777964560.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Product_Category',palette='viridis')

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount',palette='viridis')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4752\2197796482.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount',palette='viridis')
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# From above graph we can see that most of the sold product are from Food, Clothinng and Electronics category

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders',palette='viridis')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4752\2753330290.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders',palette='viridis')
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# Conclusion:
#
# Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category
#
# Thank You !
